# %% [markdown]
# <a href="https://colab.research.google.com/github/lydiasharon/Automatic-Ticket-Classification/blob/main/experement_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install pandas

# %%
import pandas as pd

# %%
df = pd.read_csv('sample_database.csv')

# %%
df.head()
# Out:
#    id     name  age       city  salary
# 0   1    Alice   25  Hyderabad   50000
# 1   2      Bob   30  Bangalore   60000
# 2   3  Charlie   28    Chennai   55000
# 3   4    Diana   35     Mumbai   70000
# 4   5     Evan   22      Delhi   45000

# %%
df.
